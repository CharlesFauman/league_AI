# %%
# imports
# nn
import tensorflow as tf
import numpy as np

# data
import urllib.parse
import urllib.request
import json
import csv

# %%
# load in data
site = "https://na1.api.riotgames.com"
key = "?api_key=RGAPI-04987748-608a-43fa-b510-1f712f391b8e"

# %%
champions_url = urllib.request.urlopen(site+"/lol/static-data/v3/champions" + key)
champions_data = champions_url.read()
champions_encoding = champions_url.info().get_content_charset('utf-8')
champions = json.loads(champions_data.decode(champions_encoding))['data']

# %%
champions
# Out:
# {'Aatrox': {'id': 266,
#   'key': 'Aatrox',
#   'name': 'Aatrox',
#   'title': 'the Darkin Blade'},
#  'Ahri': {'id': 103,
#   'key': 'Ahri',
#   'name': 'Ahri',
#   'title': 'the Nine-Tailed Fox'},
#  'Akali': {'id': 84,
#   'key': 'Akali',
#   'name': 'Akali',
#   'title': 'the Fist of Shadow'},
#  'Alistar': {'id': 12,
#   'key': 'Alistar',
#   'name': 'Alistar',
#   'title': 'the Minotaur'},
#  'Amumu': {'id': 32,
#   'key': 'Amumu',
#   'name': 'Amumu',
#   'title': 'the Sad Mummy'},
#  'Anivia': {'id': 34,
#   'key': 'Anivia',
#   'name': 'Anivia',
#   'title': 'the Cryophoenix'},
#  'Annie': {'id': 1,
#   'key': 'Annie',
#   'name': 'Annie',
#   'title': 'the Dark Child'},
#  'Ashe': {'id': 22,
#   'key': 'Ashe',
#   'name': 'Ashe',
#   'title': 'the Frost Archer'},
#  'AurelionSol': {'id': 136,
#   'key': 'AurelionSol',
#   'name': 'Aurelion Sol',
#   'title': 'The Star Forger'},
#  'Azir': {'id': 268,
#   'key': 'Azir',
#   'name': 'Azir',
# ...

# %%
len(champions)
# Out:
# 139

# %%
for champion in champions:
   champions[champion] = champions[champion]['id']

# %%
id_to_champ = dict()
for key, value in champions.items():
   id_to_champ[value] = key

# %%
id_to_champ
# Out:
# {1: 'Annie',
#  2: 'Olaf',
#  3: 'Galio',
#  4: 'TwistedFate',
#  5: 'XinZhao',
#  6: 'Urgot',
#  7: 'Leblanc',
#  8: 'Vladimir',
#  9: 'Fiddlesticks',
#  10: 'Kayle',
#  11: 'MasterYi',
#  12: 'Alistar',
#  13: 'Ryze',
#  14: 'Sion',
#  15: 'Sivir',
#  16: 'Soraka',
#  17: 'Teemo',
#  18: 'Tristana',
#  19: 'Warwick',
#  20: 'Nunu',
#  21: 'MissFortune',
#  22: 'Ashe',
#  23: 'Tryndamere',
#  24: 'Jax',
#  25: 'Morgana',
#  26: 'Zilean',
#  27: 'Singed',
#  28: 'Evelynn',
#  29: 'Twitch',
#  30: 'Karthus',
#  31: 'Chogath',
#  32: 'Amumu',
#  33: 'Rammus',
#  34: 'Anivia',
#  35: 'Shaco',
#  36: 'DrMundo',
#  37: 'Sona',
#  38: 'Kassadin',
#  39: 'Irelia',
#  40: 'Janna',
#  41: 'Gangplank',
#  42: 'Corki',
#  43: 'Karma',
#  44: 'Taric',
#  45: 'Veigar',
#  48: 'Trundle',
#  50: 'Swain',
#  51: 'Caitlyn',
#  53: 'Blitzcrank',
#  54: 'Malphite',
#  55: 'Katarina',
#  56: 'Nocturne',
#  57: 'Maokai',
#  58: 'Renekton',
#  59: 'JarvanIV',
#  60: 'Elise',
#  61: 'Orianna',
# ...

# %%
rankings_file = csv.DictReader(open("rankings.txt", "r"))
player_rankings = dict()

# %%
for row in rankings_file:
    if(row['mmr'] != '0'):
        player_rankings[row['name']] = int(row['mmr'])

# %%
sorted_players = sorted(player_rankings, key=player_rankings.get, reverse=True)

# %%
sorted_players[0:10]
# Out:
# ['fqfly',
#  'tfblade',
#  'yoplait63',
#  'ssumdayday',
#  'wxelovator',
#  'hakuho',
#  'qweasdzxc2',
#  'wiggilyad',
#  'ukp%C3%B1e%C3%B8%C3%B8',
#  'wiggily']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-846a91ef8466> in <module>()
# ----> 1 player_rankings["gav228"]
#
# KeyError: 'gav228'

# %%
summoner_urlname = site+"/lol/summoner/v3/summoners/by-name/" + "goooshlrific" + key
summoner_urlname
# Out:
# 'https://na1.api.riotgames.com/lol/summoner/v3/summoners/by-name/goooshlrific?api_key=RGAPI-04987748-608a-43fa-b510-1f712f391b8e'

# %%
summoner_url = urllib.request.urlopen(summoner_urlname)
summoner_data = summoner_url.read()

# %%
summoner_encoding = summoner_url.info().get_content_charset('utf-8')
summoner = json.loads(summoner_data.decode(summoner_encoding))
summoner_id = summoner['accountId']
summoner_id
# Out:
# 201014208

# %%
matches_urlname = site + "/lol/match/v3/matchlists/by-account/" + str(summoner_id) + key
matches_urlname
# Out:
# 'https://na1.api.riotgames.com/lol/match/v3/matchlists/by-account/201014208?api_key=RGAPI-04987748-608a-43fa-b510-1f712f391b8e'

# %%
matches_url = urllib.request.urlopen(matches_urlname)
matches_data = matches_url.read()

# %%
matches_data
# Out:
# b'{"matches":[{"platformId":"NA1","gameId":2731739259,"champion":89,"queue":420,"season":11,"timestamp":1520110519827,"role":"DUO_SUPPORT","lane":"BOTTOM"},{"platformId":"NA1","gameId":2731734285,"champion":98,"queue":420,"season":11,"timestamp":1520108948279,"role":"DUO_SUPPORT","lane":"BOTTOM"},{"platformId":"NA1","gameId":2731708276,"champion":12,"queue":420,"season":11,"timestamp":1520107020874,"role":"DUO_SUPPORT","lane":"BOTTOM"},{"platformId":"NA1","gameId":2731702247,"champion":89,"queue":420,"season":11,"timestamp":1520104986191,"role":"DUO_SUPPORT","lane":"BOTTOM"},{"platformId":"NA1","gameId":2730797832,"champion":59,"queue":420,"season":11,"timestamp":1520021810124,"role":"NONE","lane":"JUNGLE"},{"platformId":"NA1","gameId":2730782662,"champion":141,"queue":420,"season":11,"timestamp":1520019289288,"role":"NONE","lane":"JUNGLE"},{"platformId":"NA1","gameId":2730748877,"champion":141,"queue":420,"season":11,"timestamp":1520017168236,"role":"NONE","lane":"JUNGLE"},{"platfor
# ...

# %%
matches_encoding = matches_url.info().get_content_charset('utf-8')
matches = json.loads(matches_data.decode(matches_encoding))['matches']

# %%
game_ids = dict()
game_ids['goooshlrific'] = set()
for match in matches:
    game_ids['goooshlrific'].add(match['gameId'])

# %%
game_urlname = site + "/lol/match/v3/matches/" + str(2723845653) + key
game_urlname
# Out:
# 'https://na1.api.riotgames.com/lol/match/v3/matches/2723845653?api_key=RGAPI-04987748-608a-43fa-b510-1f712f391b8e'

# %%
game_url = urllib.request.urlopen(game_urlname)
game_data = game_url.read()
game_data
# Out:
# b'{"gameId":2723845653,"platformId":"NA1","gameCreation":1519187534899,"gameDuration":1886,"queueId":420,"mapId":11,"seasonId":11,"gameVersion":"8.3.217.1022","gameMode":"CLASSIC","gameType":"MATCHED_GAME","teams":[{"teamId":100,"win":"Fail","firstBlood":true,"firstTower":true,"firstInhibitor":false,"firstBaron":false,"firstDragon":false,"firstRiftHerald":false,"towerKills":4,"inhibitorKills":0,"baronKills":0,"dragonKills":0,"vilemawKills":0,"riftHeraldKills":0,"dominionVictoryScore":0,"bans":[{"championId":8,"pickTurn":1},{"championId":28,"pickTurn":2},{"championId":-1,"pickTurn":3},{"championId":92,"pickTurn":4},{"championId":142,"pickTurn":5}]},{"teamId":200,"win":"Win","firstBlood":false,"firstTower":false,"firstInhibitor":true,"firstBaron":true,"firstDragon":true,"firstRiftHerald":false,"towerKills":8,"inhibitorKills":2,"baronKills":2,"dragonKills":2,"vilemawKills":0,"riftHeraldKills":0,"dominionVictoryScore":0,"bans":[{"championId":41,"pickTurn":6},{"championId":142,"pickTurn":
# ...

# %%
game_encoding = game_url.info().get_content_charset('utf-8')
game = json.loads(game_data.decode(game_encoding))
game
# Out:
# {'gameCreation': 1519187534899,
#  'gameDuration': 1886,
#  'gameId': 2723845653,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '8.3.217.1022',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#    'player': {'accountId': 244721782,
#     'currentAccountId': 244721782,
#     'currentPlatformId': 'NA1',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/244721782',
#     'platformId': 'NA1',
#     'profileIcon': 4,
#     'summonerId': 92319091,
#     'summonerName': '5hour energy'}},
#   {'participantId': 2,
#    'player': {'accountId': 40233587,
#     'currentAccountId': 40233587,
#     'currentPlatformId': 'NA1',
#     'matchHistoryUri': '/v1/stats/player_history/NA/40233587',
#     'platformId': 'NA',
#     'profileIcon': 3352,
#     'summonerId': 25739133,
#     'summonerName': 'ı am'}},
#   {'participantId': 3,
#    'player': {'accountId': 48340486,
#     'currentAccountId': 48340486,
#     'currentPlatformId': 'NA1',
# ...

# %%
participant_champs = dict()
for participant in game['participants']:
    participantId = participant['participantId']
    champion_id = participant['championId']
    participant_champs[participantId] = champion_id

# %%
for player in game['participantIdentities']:
    name = urllib.parse.quote_plus(''.join(c.lower() for c in player['player']['summonerName'] if not c.isspace()))
    champname = "(" + id_to_champ[participant_champs[player['participantId']]] +")"
    print( str(player['participantId']) + ". " + name + champname + ": ", end ='')
    if name in player_rankings:
        print(player_rankings[name])
    else:
        print("doesn't play enough ranked")
# Out:
# 1. slightlysexual(Sion): 2044
# 2. nerfels(Fiddlesticks): 2286
# 3. phanntastic(Vayne): 2035
# 4. kordopa0(TwistedFate): 1979
# 5. manuelpopa(Ivern): 2104
# 6. goooshlrific(Shen): 2137
# 7. w%C3%A4nheda(Xayah): 1990
# 8. chronnik(Azir): 2066
# 9. nazzur(JarvanIV): 2051
# 10. jmac379(Soraka): 2338

# %%
participant_MMRs = dict()
for player in game['participantIdentities']:
    name = urllib.parse.quote_plus(''.join(c.lower() for c in player['player']['summonerName'] if not c.isspace()))
    if name in player_rankings:
        participant_MMRs[player['participantId']] = player_rankings[name]
if(len(participant_MMRs) != 10):
    print("well, we must stop now")

# %%
team_win = 200
for item in game['teams']:
    if item['teamId'] == 100:
        if item['win'] == 'Win':
            team_win = 100
    break

# %%
match = dict()
winteam = list()
loseteam = list()
for participant in game['participants']:
    player_info = dict()
    player_info['championId'] = participant['championId']
    player_info['MMR'] = participant_MMRs[participant['participantId']]
    if participant['teamId'] == team_win:
        winteam.append(player_info)
    else:
        loseteam.append(player_info)
match['win'] = winteam
match['lose'] = loseteam

# %%
print(match)
# Out:
# {'win': [{'championId': 14, 'MMR': 2044}, {'championId': 9, 'MMR': 2286}, {'championId': 67, 'MMR': 2035}, {'championId': 4, 'MMR': 1979}, {'championId': 427, 'MMR': 2104}], 'lose': [{'championId': 98, 'MMR': 2137}, {'championId': 498, 'MMR': 1990}, {'championId': 268, 'MMR': 2066}, {'championId': 59, 'MMR': 2051}, {'championId': 16, 'MMR': 2338}]}

# %%
thingy = {2721779898: {'win': [{'championId': 14, 'MMR': 2044}, {'championId': 9, 'MMR': 2286}, {'championId': 67, 'MMR': 2035}, {'championId': 4, 'MMR': 1979}, {'championId': 427, 'MMR': 2104}], 'lose': [{'championId': 98, 'MMR': 2137}, {'championId': 498, 'MMR': 1990}, {'championId': 268, 'MMR': 2066}, {'championId': 59, 'MMR': 2051}, {'championId': 16, 'MMR': 2338}]}}

# %%
info = {'gameId': 2724594688, 'platformId': 'NA1', 'gameCreation': 1519278966427, 'gameDuration': 1958, 'queueId': 420, 'mapId': 11, 'seasonId': 11, 'gameVersion': '8.3.217.1022', 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'teams': [{'teamId': 100, 'win': 'Win', 'firstBlood': True, 'firstTower': True, 'firstInhibitor': True, 'firstBaron': False, 'firstDragon': False, 'firstRiftHerald': False, 'towerKills': 9, 'inhibitorKills': 2, 'baronKills': 1, 'dragonKills': 0, 'vilemawKills': 0, 'riftHeraldKills': 0, 'dominionVictoryScore': 0, 'bans': [{'championId': 142, 'pickTurn': 1}, {'championId': -1, 'pickTurn': 2}, {'championId': 121, 'pickTurn': 3}, {'championId': 41, 'pickTurn': 4}, {'championId': 164, 'pickTurn': 5}]}, {'teamId': 200, 'win': 'Fail', 'firstBlood': False, 'firstTower': False, 'firstInhibitor': False, 'firstBaron': True, 'firstDragon': True, 'firstRiftHerald': False, 'towerKills': 3, 'inhibitorKills': 0, 'baronKills': 1, 'dragonKills': 2, 'vilemawKills': 0, 'riftHeraldKills': 0, 'dominionVictoryScore': 0, 'bans': [{'championId': 201, 'pickTurn': 6}, {'championId': 164, 'pickTurn': 7}, {'championId': 154, 'pickTurn': 8}, {'championId': 498, 'pickTurn': 9}, {'championId': 92, 'pickTurn': 10}]}], 'participants': [{'participantId': 1, 'teamId': 100, 'championId': 126, 'spell1Id': 4, 'spell2Id': 12, 'highestAchievedSeasonTier': 'MASTER', 'stats': {'participantId': 1, 'win': True, 'item0': 1055, 'item1': 3142, 'item2': 2031, 'item3': 3147, 'item4': 3047, 'item5': 3071, 'item6': 3363, 'kills': 3, 'deaths': 6, 'assists': 11, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 651, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 106480, 'magicDamageDealt': 15221, 'physicalDamageDealt': 91259, 'trueDamageDealt': 0, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 19630, 'magicDamageDealtToChampions': 2977, 'physicalDamageDealtToChampions': 16653, 'trueDamageDealtToChampions': 0, 'totalHeal': 794, 'totalUnitsHealed': 1, 'damageSelfMitigated': 10108, 'damageDealtToObjectives': 11423, 'damageDealtToTurrets': 5322, 'visionScore': 26, 'timeCCingOthers': 5, 'totalDamageTaken': 17328, 'magicalDamageTaken': 7044, 'physicalDamageTaken': 9904, 'trueDamageTaken': 380, 'goldEarned': 11808, 'goldSpent': 10600, 'turretKills': 3, 'inhibitorKills': 2, 'totalMinionsKilled': 189, 'neutralMinionsKilled': 4, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 183, 'champLevel': 15, 'visionWardsBoughtInGame': 0, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 12, 'wardsKilled': 10, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': True, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8229, 'perk0Var1': 1068, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8226, 'perk1Var1': 1608, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8210, 'perk2Var1': 11, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8237, 'perk3Var1': 673, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 9111, 'perk4Var1': 541, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8014, 'perk5Var1': 305, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8200, 'perkSubStyle': 8000}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'10-20': 6.6, '0-10': 7.6000000000000005, '20-30': 4.3}, 'xpPerMinDeltas': {'10-20': 392.4, '0-10': 404.3, '20-30': 415.1}, 'goldPerMinDeltas': {'10-20': 290.5, '0-10': 265.8, '20-30': 419.20000000000005}, 'csDiffPerMinDeltas': {'10-20': -1.6, '0-10': 1.3000000000000003, '20-30': -0.8999999999999999}, 'xpDiffPerMinDeltas': {'10-20': -79.1, '0-10': -59.39999999999998, '20-30': -66.70000000000002}, 'damageTakenPerMinDeltas': {'10-20': 450.8, '0-10': 323.7, '20-30': 765.6}, 'damageTakenDiffPerMinDeltas': {'10-20': -295.59999999999997, '0-10': 28.799999999999983, '20-30': -690.1999999999999}, 'role': 'SOLO', 'lane': 'TOP'}}, {'participantId': 2, 'teamId': 100, 'championId': 117, 'spell1Id': 14, 'spell2Id': 4, 'highestAchievedSeasonTier': 'CHALLENGER', 'stats': {'participantId': 2, 'win': True, 'item0': 3098, 'item1': 2055, 'item2': 3504, 'item3': 3117, 'item4': 3107, 'item5': 3222, 'item6': 3364, 'kills': 2, 'deaths': 4, 'assists': 22, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'killingSprees': 0, 'longestTimeSpentLiving': 687, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 19512, 'magicDamageDealt': 13056, 'physicalDamageDealt': 5803, 'trueDamageDealt': 652, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 6061, 'magicDamageDealtToChampions': 4600, 'physicalDamageDealtToChampions': 809, 'trueDamageDealtToChampions': 652, 'totalHeal': 1961, 'totalUnitsHealed': 4, 'damageSelfMitigated': 6140, 'damageDealtToObjectives': 3377, 'damageDealtToTurrets': 2546, 'visionScore': 78, 'timeCCingOthers': 24, 'totalDamageTaken': 11672, 'magicalDamageTaken': 3637, 'physicalDamageTaken': 7416, 'trueDamageTaken': 618, 'goldEarned': 10355, 'goldSpent': 9400, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 17, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 202, 'champLevel': 15, 'visionWardsBoughtInGame': 10, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 35, 'wardsKilled': 13, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': True, 'firstInhibitorKill': False, 'firstInhibitorAssist': True, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8214, 'perk0Var1': 488, 'perk0Var2': 3167, 'perk0Var3': 0, 'perk1': 8226, 'perk1Var1': 1806, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8234, 'perk2Var1': 18, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8237, 'perk3Var1': 346, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8304, 'perk4Var1': 8, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8347, 'perk5Var1': 0, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8200, 'perkSubStyle': 8300}, 'timeline': {'participantId': 2, 'creepsPerMinDeltas': {'10-20': 0.5, '0-10': 0.5, '20-30': 0.6}, 'xpPerMinDeltas': {'10-20': 308, '0-10': 241.39999999999998, '20-30': 488.3}, 'goldPerMinDeltas': {'10-20': 244.9, '0-10': 241.1, '20-30': 373.3}, 'csDiffPerMinDeltas': {'10-20': 0.20000000000000018, '0-10': 2.220446049250313e-16, '20-30': 0.9499999999999997}, 'xpDiffPerMinDeltas': {'10-20': -16.549999999999983, '0-10': -46.80000000000001, '20-30': 182.15000000000003}, 'damageTakenPerMinDeltas': {'10-20': 149, '0-10': 292.5, '20-30': 639.1}, 'damageTakenDiffPerMinDeltas': {'10-20': -42.3, '0-10': -33.049999999999955, '20-30': -32.25}, 'role': 'DUO_SUPPORT', 'lane': 'BOTTOM'}}, {'participantId': 3, 'teamId': 100, 'championId': 18, 'spell1Id': 4, 'spell2Id': 7, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 3, 'win': True, 'item0': 3006, 'item1': 3139, 'item2': 3036, 'item3': 3094, 'item4': 3031, 'item5': 3087, 'item6': 3363, 'kills': 14, 'deaths': 2, 'assists': 9, 'largestKillingSpree': 12, 'largestMultiKill': 2, 'killingSprees': 1, 'longestTimeSpentLiving': 578, 'doubleKills': 3, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 266609, 'magicDamageDealt': 92719, 'physicalDamageDealt': 168181, 'trueDamageDealt': 5708, 'largestCriticalStrike': 933, 'totalDamageDealtToChampions': 47900, 'magicDamageDealtToChampions': 13347, 'physicalDamageDealtToChampions': 33285, 'trueDamageDealtToChampions': 1268, 'totalHeal': 7713, 'totalUnitsHealed': 5, 'damageSelfMitigated': 17610, 'damageDealtToObjectives': 28138, 'damageDealtToTurrets': 14332, 'visionScore': 33, 'timeCCingOthers': 11, 'totalDamageTaken': 19468, 'magicalDamageTaken': 5791, 'physicalDamageTaken': 13171, 'trueDamageTaken': 506, 'goldEarned': 17767, 'goldSpent': 16805, 'turretKills': 3, 'inhibitorKills': 0, 'totalMinionsKilled': 283, 'neutralMinionsKilled': 28, 'neutralMinionsKilledTeamJungle': 8, 'neutralMinionsKilledEnemyJungle': 16, 'totalTimeCrowdControlDealt': 195, 'champLevel': 17, 'visionWardsBoughtInGame': 3, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 15, 'wardsKilled': 12, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': True, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': True, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8021, 'perk0Var1': 9712, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 9101, 'perk1Var1': 2182, 'perk1Var2': 3391, 'perk1Var3': 0, 'perk2': 9103, 'perk2Var1': 14, 'perk2Var2': 50, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 1058, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8234, 'perk4Var1': 21, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8236, 'perk5Var1': 28, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8200}, 'timeline': {'participantId': 3, 'creepsPerMinDeltas': {'10-20': 9.600000000000001, '0-10': 7, '20-30': 9.7}, 'xpPerMinDeltas': {'10-20': 412.6, '0-10': 282.7, '20-30': 724.5}, 'goldPerMinDeltas': {'10-20': 403.6, '0-10': 309.6, '20-30': 771.3}, 'csDiffPerMinDeltas': {'10-20': 0.20000000000000018, '0-10': 2.220446049250313e-16, '20-30': 0.9499999999999997}, 'xpDiffPerMinDeltas': {'10-20': -16.549999999999983, '0-10': -46.80000000000001, '20-30': 182.15000000000003}, 'damageTakenPerMinDeltas': {'10-20': 546.3, '0-10': 295.2, '20-30': 721.8000000000001}, 'damageTakenDiffPerMinDeltas': {'10-20': -42.3, '0-10': -33.049999999999955, '20-30': -32.25}, 'role': 'DUO_CARRY', 'lane': 'BOTTOM'}}, {'participantId': 4, 'teamId': 100, 'championId': 136, 'spell1Id': 4, 'spell2Id': 14, 'highestAchievedSeasonTier': 'CHALLENGER', 'stats': {'participantId': 4, 'win': True, 'item0': 3030, 'item1': 2033, 'item2': 3116, 'item3': 3009, 'item4': 3151, 'item5': 1058, 'item6': 3363, 'kills': 7, 'deaths': 8, 'assists': 10, 'largestKillingSpree': 2, 'largestMultiKill': 2, 'killingSprees': 2, 'longestTimeSpentLiving': 355, 'doubleKills': 1, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 138748, 'magicDamageDealt': 129999, 'physicalDamageDealt': 7815, 'trueDamageDealt': 934, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 25046, 'magicDamageDealtToChampions': 22678, 'physicalDamageDealtToChampions': 1434, 'trueDamageDealtToChampions': 934, 'totalHeal': 3564, 'totalUnitsHealed': 1, 'damageSelfMitigated': 11468, 'damageDealtToObjectives': 6152, 'damageDealtToTurrets': 1632, 'visionScore': 33, 'timeCCingOthers': 38, 'totalDamageTaken': 29781, 'magicalDamageTaken': 15148, 'physicalDamageTaken': 14210, 'trueDamageTaken': 422, 'goldEarned': 13132, 'goldSpent': 11650, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 191, 'neutralMinionsKilled': 10, 'neutralMinionsKilledTeamJungle': 9, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 545, 'champLevel': 15, 'visionWardsBoughtInGame': 4, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 13, 'wardsKilled': 2, 'firstBloodKill': True, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': True, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8230, 'perk0Var1': 17, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8226, 'perk1Var1': 1341, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8234, 'perk2Var1': 22, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8232, 'perk3Var1': 4, 'perk3Var2': 10, 'perk3Var3': 0, 'perk4': 8009, 'perk4Var1': 3304, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8014, 'perk5Var1': 379, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8200, 'perkSubStyle': 8000}, 'timeline': {'participantId': 4, 'creepsPerMinDeltas': {'10-20': 6.199999999999999, '0-10': 7.4, '20-30': 5.5}, 'xpPerMinDeltas': {'10-20': 357.1, '0-10': 396.20000000000005, '20-30': 440.29999999999995}, 'goldPerMinDeltas': {'10-20': 336.6, '0-10': 350.5, '20-30': 426.2}, 'csDiffPerMinDeltas': {'10-20': 0.30000000000000004, '0-10': 2.2, '20-30': -2.1}, 'xpDiffPerMinDeltas': {'10-20': 13.699999999999989, '0-10': 41.50000000000003, '20-30': -195.20000000000002}, 'damageTakenPerMinDeltas': {'10-20': 847.3, '0-10': 607.3, '20-30': 1114}, 'damageTakenDiffPerMinDeltas': {'10-20': 300.99999999999994, '0-10': 185.2, '20-30': 117.59999999999997}, 'role': 'SOLO', 'lane': 'MIDDLE'}}, {'participantId': 5, 'teamId': 100, 'championId': 113, 'spell1Id': 4, 'spell2Id': 11, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 5, 'win': True, 'item0': 1409, 'item1': 2055, 'item2': 3083, 'item3': 3047, 'item4': 3193, 'item5': 3082, 'item6': 3364, 'kills': 4, 'deaths': 1, 'assists': 14, 'largestKillingSpree': 3, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 1823, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 122179, 'magicDamageDealt': 48082, 'physicalDamageDealt': 61594, 'trueDamageDealt': 12502, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 11128, 'magicDamageDealtToChampions': 5180, 'physicalDamageDealtToChampions': 5349, 'trueDamageDealtToChampions': 598, 'totalHeal': 6914, 'totalUnitsHealed': 1, 'damageSelfMitigated': 37454, 'damageDealtToObjectives': 5613, 'damageDealtToTurrets': 2436, 'visionScore': 92, 'timeCCingOthers': 31, 'totalDamageTaken': 33983, 'magicalDamageTaken': 12506, 'physicalDamageTaken': 20975, 'trueDamageTaken': 501, 'goldEarned': 11906, 'goldSpent': 10550, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 48, 'neutralMinionsKilled': 105, 'neutralMinionsKilledTeamJungle': 64, 'neutralMinionsKilledEnemyJungle': 17, 'totalTimeCrowdControlDealt': 448, 'champLevel': 15, 'visionWardsBoughtInGame': 6, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 49, 'wardsKilled': 9, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': True, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8021, 'perk0Var1': 1568, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 9101, 'perk1Var1': 322, 'perk1Var2': 940, 'perk1Var3': 0, 'perk2': 9104, 'perk2Var1': 18, 'perk2Var2': 10, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 248, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8136, 'perk4Var1': 25, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8126, 'perk5Var1': 550, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8100}, 'timeline': {'participantId': 5, 'creepsPerMinDeltas': {'10-20': 1.1, '0-10': 1.3, '20-30': 1.5}, 'xpPerMinDeltas': {'10-20': 363.4, '0-10': 388.6, '20-30': 383}, 'goldPerMinDeltas': {'10-20': 336.6, '0-10': 325.8, '20-30': 334.2}, 'csDiffPerMinDeltas': {'10-20': 0.3, '0-10': -0.29999999999999993, '20-30': 0.7}, 'xpDiffPerMinDeltas': {'10-20': -212.10000000000002, '0-10': 27.99999999999997, '20-30': -16.599999999999994}, 'damageTakenPerMinDeltas': {'10-20': 743.6, '0-10': 459.1, '20-30': 1656.5}, 'damageTakenDiffPerMinDeltas': {'10-20': -217.49999999999994, '0-10': -121.9, '20-30': -35.200000000000045}, 'role': 'NONE', 'lane': 'JUNGLE'}}, {'participantId': 6, 'teamId': 200, 'championId': 51, 'spell1Id': 7, 'spell2Id': 4, 'highestAchievedSeasonTier': 'MASTER', 'stats': {'participantId': 6, 'win': False, 'item0': 3035, 'item1': 3140, 'item2': 3006, 'item3': 3094, 'item4': 3087, 'item5': 3031, 'item6': 3363, 'kills': 6, 'deaths': 6, 'assists': 6, 'largestKillingSpree': 2, 'largestMultiKill': 2, 'killingSprees': 2, 'longestTimeSpentLiving': 706, 'doubleKills': 1, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 208473, 'magicDamageDealt': 46728, 'physicalDamageDealt': 152915, 'trueDamageDealt': 8830, 'largestCriticalStrike': 1702, 'totalDamageDealtToChampions': 21349, 'magicDamageDealtToChampions': 5296, 'physicalDamageDealtToChampions': 15843, 'trueDamageDealtToChampions': 210, 'totalHeal': 4819, 'totalUnitsHealed': 4, 'damageSelfMitigated': 12182, 'damageDealtToObjectives': 10892, 'damageDealtToTurrets': 4127, 'visionScore': 29, 'timeCCingOthers': 18, 'totalDamageTaken': 19900, 'magicalDamageTaken': 5864, 'physicalDamageTaken': 13712, 'trueDamageTaken': 323, 'goldEarned': 13102, 'goldSpent': 13310, 'turretKills': 1, 'inhibitorKills': 0, 'totalMinionsKilled': 256, 'neutralMinionsKilled': 11, 'neutralMinionsKilledTeamJungle': 5, 'neutralMinionsKilledEnemyJungle': 6, 'totalTimeCrowdControlDealt': 103, 'champLevel': 15, 'visionWardsBoughtInGame': 4, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 9, 'wardsKilled': 7, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8021, 'perk0Var1': 6433, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 9101, 'perk1Var1': 1404, 'perk1Var2': 2633, 'perk1Var3': 0, 'perk2': 9104, 'perk2Var1': 14, 'perk2Var2': 30, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 398, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8234, 'perk4Var1': 26, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8236, 'perk5Var1': 28, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8200}, 'timeline': {'participantId': 6, 'creepsPerMinDeltas': {'10-20': 9, '0-10': 7, '20-30': 7.3}, 'xpPerMinDeltas': {'10-20': 474.59999999999997, '0-10': 318.9, '20-30': 512.5}, 'goldPerMinDeltas': {'10-20': 385.6, '0-10': 292.1, '20-30': 428.6}, 'csDiffPerMinDeltas': {'10-20': -0.20000000000000018, '0-10': -2.220446049250313e-16, '20-30': -0.9499999999999997}, 'xpDiffPerMinDeltas': {'10-20': 16.549999999999983, '0-10': 46.80000000000001, '20-30': -182.15000000000003}, 'damageTakenPerMinDeltas': {'10-20': 373.6, '0-10': 325.1, '20-30': 696}, 'damageTakenDiffPerMinDeltas': {'10-20': 42.3, '0-10': 33.049999999999955, '20-30': 32.25}, 'role': 'DUO_CARRY', 'lane': 'BOTTOM'}}, {'participantId': 7, 'teamId': 200, 'championId': 432, 'spell1Id': 4, 'spell2Id': 14, 'highestAchievedSeasonTier': 'DIAMOND', 'stats': {'participantId': 7, 'win': False, 'item0': 3025, 'item1': 2055, 'item2': 3114, 'item3': 3117, 'item4': 3092, 'item5': 3801, 'item6': 3364, 'kills': 2, 'deaths': 6, 'assists': 8, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 1060, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 16896, 'magicDamageDealt': 12440, 'physicalDamageDealt': 3637, 'trueDamageDealt': 819, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 8901, 'magicDamageDealtToChampions': 6793, 'physicalDamageDealtToChampions': 1288, 'trueDamageDealtToChampions': 819, 'totalHeal': 3135, 'totalUnitsHealed': 4, 'damageSelfMitigated': 9356, 'damageDealtToObjectives': 926, 'damageDealtToTurrets': 322, 'visionScore': 107, 'timeCCingOthers': 24, 'totalDamageTaken': 18819, 'magicalDamageTaken': 9423, 'physicalDamageTaken': 8952, 'trueDamageTaken': 443, 'goldEarned': 8130, 'goldSpent': 7675, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 27, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 130, 'champLevel': 13, 'visionWardsBoughtInGame': 7, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 64, 'wardsKilled': 17, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8112, 'perk0Var1': 741, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8126, 'perk1Var1': 249, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8136, 'perk2Var1': 33, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8105, 'perk3Var1': 4, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8234, 'perk4Var1': 23, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8232, 'perk5Var1': 2, 'perk5Var2': 50, 'perk5Var3': 0, 'perkPrimaryStyle': 8100, 'perkSubStyle': 8200}, 'timeline': {'participantId': 7, 'creepsPerMinDeltas': {'10-20': 0.7, '0-10': 0.5, '20-30': 1.1}, 'xpPerMinDeltas': {'10-20': 279.1, '0-10': 298.8, '20-30': 336}, 'goldPerMinDeltas': {'10-20': 226.5, '0-10': 213.9, '20-30': 253.10000000000002}, 'csDiffPerMinDeltas': {'10-20': -0.20000000000000018, '0-10': -2.220446049250313e-16, '20-30': -0.9499999999999997}, 'xpDiffPerMinDeltas': {'10-20': 16.549999999999983, '0-10': 46.80000000000001, '20-30': -182.15000000000003}, 'damageTakenPerMinDeltas': {'10-20': 406.29999999999995, '0-10': 328.7, '20-30': 729.4}, 'damageTakenDiffPerMinDeltas': {'10-20': 42.3, '0-10': 33.049999999999955, '20-30': 32.25}, 'role': 'DUO_SUPPORT', 'lane': 'BOTTOM'}}, {'participantId': 8, 'teamId': 200, 'championId': 150, 'spell1Id': 4, 'spell2Id': 12, 'highestAchievedSeasonTier': 'MASTER', 'stats': {'participantId': 8, 'win': False, 'item0': 3022, 'item1': 3211, 'item2': 3082, 'item3': 3071, 'item4': 3111, 'item5': 1033, 'item6': 3340, 'kills': 4, 'deaths': 7, 'assists': 5, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 651, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 143470, 'magicDamageDealt': 9920, 'physicalDamageDealt': 133549, 'trueDamageDealt': 0, 'largestCriticalStrike': 305, 'totalDamageDealtToChampions': 18192, 'magicDamageDealtToChampions': 2448, 'physicalDamageDealtToChampions': 15743, 'trueDamageDealtToChampions': 0, 'totalHeal': 1153, 'totalUnitsHealed': 1, 'damageSelfMitigated': 24597, 'damageDealtToObjectives': 5011, 'damageDealtToTurrets': 2119, 'visionScore': 20, 'timeCCingOthers': 36, 'totalDamageTaken': 31858, 'magicalDamageTaken': 9911, 'physicalDamageTaken': 21359, 'trueDamageTaken': 586, 'goldEarned': 11668, 'goldSpent': 10650, 'turretKills': 1, 'inhibitorKills': 0, 'totalMinionsKilled': 217, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 988, 'champLevel': 16, 'visionWardsBoughtInGame': 4, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 12, 'wardsKilled': 2, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8214, 'perk0Var1': 1054, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8224, 'perk1Var1': 742, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8210, 'perk2Var1': 0, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8237, 'perk3Var1': 552, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8430, 'perk4Var1': 4, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8444, 'perk5Var1': 1162, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8200, 'perkSubStyle': 8400}, 'timeline': {'participantId': 8, 'creepsPerMinDeltas': {'10-20': 8.2, '0-10': 6.300000000000001, '20-30': 5.199999999999999}, 'xpPerMinDeltas': {'10-20': 471.5, '0-10': 463.7, '20-30': 481.8}, 'goldPerMinDeltas': {'10-20': 351.5, '0-10': 313, '20-30': 357.5}, 'csDiffPerMinDeltas': {'10-20': 1.6, '0-10': -1.3000000000000003, '20-30': 0.8999999999999999}, 'xpDiffPerMinDeltas': {'10-20': 79.1, '0-10': 59.39999999999998, '20-30': 66.70000000000002}, 'damageTakenPerMinDeltas': {'10-20': 746.4, '0-10': 294.9, '20-30': 1455.8}, 'damageTakenDiffPerMinDeltas': {'10-20': 295.59999999999997, '0-10': -28.799999999999983, '20-30': 690.1999999999999}, 'role': 'SOLO', 'lane': 'TOP'}}, {'participantId': 9, 'teamId': 200, 'championId': 163, 'spell1Id': 1, 'spell2Id': 4, 'highestAchievedSeasonTier': 'UNRANKED', 'stats': {'participantId': 9, 'win': False, 'item0': 1056, 'item1': 1058, 'item2': 3165, 'item3': 3151, 'item4': 3135, 'item5': 3009, 'item6': 3363, 'kills': 6, 'deaths': 7, 'assists': 3, 'largestKillingSpree': 3, 'largestMultiKill': 2, 'killingSprees': 2, 'longestTimeSpentLiving': 852, 'doubleKills': 2, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 157564, 'magicDamageDealt': 146963, 'physicalDamageDealt': 6755, 'trueDamageDealt': 3845, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 23023, 'magicDamageDealtToChampions': 22652, 'physicalDamageDealtToChampions': 371, 'trueDamageDealtToChampions': 0, 'totalHeal': 1333, 'totalUnitsHealed': 1, 'damageSelfMitigated': 8505, 'damageDealtToObjectives': 634, 'damageDealtToTurrets': 289, 'visionScore': 31, 'timeCCingOthers': 17, 'totalDamageTaken': 23525, 'magicalDamageTaken': 11574, 'physicalDamageTaken': 11152, 'trueDamageTaken': 797, 'goldEarned': 11972, 'goldSpent': 11835, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 210, 'neutralMinionsKilled': 20, 'neutralMinionsKilledTeamJungle': 16, 'neutralMinionsKilledEnemyJungle': 4, 'totalTimeCrowdControlDealt': 652, 'champLevel': 16, 'visionWardsBoughtInGame': 3, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 12, 'wardsKilled': 9, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8214, 'perk0Var1': 1458, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8226, 'perk1Var1': 2112, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8234, 'perk2Var1': 26, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8237, 'perk3Var1': 573, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8009, 'perk4Var1': 2255, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8014, 'perk5Var1': 329, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8200, 'perkSubStyle': 8000}, 'timeline': {'participantId': 9, 'creepsPerMinDeltas': {'10-20': 5.8999999999999995, '0-10': 5.199999999999999, '20-30': 7.6}, 'xpPerMinDeltas': {'10-20': 343.4, '0-10': 354.7, '20-30': 635.5}, 'goldPerMinDeltas': {'10-20': 296.29999999999995, '0-10': 306, '20-30': 449.79999999999995}, 'csDiffPerMinDeltas': {'10-20': -0.30000000000000004, '0-10': -2.2, '20-30': 2.1}, 'xpDiffPerMinDeltas': {'10-20': -13.699999999999989, '0-10': -41.50000000000003, '20-30': 195.20000000000002}, 'damageTakenPerMinDeltas': {'10-20': 546.3, '0-10': 422.1, '20-30': 996.4000000000001}, 'damageTakenDiffPerMinDeltas': {'10-20': -300.99999999999994, '0-10': -185.2, '20-30': -117.59999999999997}, 'role': 'SOLO', 'lane': 'MIDDLE'}}, {'participantId': 10, 'teamId': 200, 'championId': 24, 'spell1Id': 4, 'spell2Id': 11, 'highestAchievedSeasonTier': 'CHALLENGER', 'stats': {'participantId': 10, 'win': False, 'item0': 0, 'item1': 3053, 'item2': 3078, 'item3': 3047, 'item4': 1413, 'item5': 0, 'item6': 3340, 'kills': 3, 'deaths': 4, 'assists': 7, 'largestKillingSpree': 3, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 1291, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 168053, 'magicDamageDealt': 63799, 'physicalDamageDealt': 91898, 'trueDamageDealt': 12355, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 12185, 'magicDamageDealtToChampions': 3430, 'physicalDamageDealtToChampions': 7355, 'trueDamageDealtToChampions': 1399, 'totalHeal': 10938, 'totalUnitsHealed': 1, 'damageSelfMitigated': 26834, 'damageDealtToObjectives': 9512, 'damageDealtToTurrets': 1919, 'visionScore': 38, 'timeCCingOthers': 25, 'totalDamageTaken': 37469, 'magicalDamageTaken': 14533, 'physicalDamageTaken': 21635, 'trueDamageTaken': 1300, 'goldEarned': 11359, 'goldSpent': 11408, 'turretKills': 1, 'inhibitorKills': 0, 'totalMinionsKilled': 39, 'neutralMinionsKilled': 150, 'neutralMinionsKilledTeamJungle': 100, 'neutralMinionsKilledEnemyJungle': 14, 'totalTimeCrowdControlDealt': 576, 'champLevel': 15, 'visionWardsBoughtInGame': 7, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 20, 'wardsKilled': 6, 'firstBloodKill': False, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8005, 'perk0Var1': 720, 'perk0Var2': 446, 'perk0Var3': 273, 'perk1': 9111, 'perk1Var1': 725, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 9104, 'perk2Var1': 14, 'perk2Var2': 10, 'perk2Var3': 0, 'perk3': 8014, 'perk3Var1': 121, 'perk3Var2': 0, 'perk3Var3': 0, 'perk4': 8304, 'perk4Var1': 8, 'perk4Var2': 3, 'perk4Var3': 0, 'perk5': 8321, 'perk5Var1': 2, 'perk5Var2': 0, 'perk5Var3': 0, 'perkPrimaryStyle': 8000, 'perkSubStyle': 8300}, 'timeline': {'participantId': 10, 'creepsPerMinDeltas': {'10-20': 0.8, '0-10': 1.6, '20-30': 0.7999999999999999}, 'xpPerMinDeltas': {'10-20': 575.5, '0-10': 360.6, '20-30': 399.6}, 'goldPerMinDeltas': {'10-20': 351.7, '0-10': 331.2, '20-30': 306}, 'csDiffPerMinDeltas': {'10-20': -0.3, '0-10': 0.29999999999999993, '20-30': -0.7}, 'xpDiffPerMinDeltas': {'10-20': 212.10000000000002, '0-10': -27.99999999999997, '20-30': 16.599999999999994}, 'damageTakenPerMinDeltas': {'10-20': 961.0999999999999, '0-10': 581, '20-30': 1691.7}, 'damageTakenDiffPerMinDeltas': {'10-20': 217.49999999999994, '0-10': 121.9, '20-30': 35.200000000000045}, 'role': 'NONE', 'lane': 'JUNGLE'}}], 'participantIdentities': [{'participantId': 1, 'player': {'platformId': 'NA1', 'accountId': 208040964, 'summonerName': 'Bánh Bao Chiên', 'summonerId': 45167717, 'currentPlatformId': 'NA1', 'currentAccountId': 208040964, 'matchHistoryUri': '/v1/stats/player_history/NA1/208040964', 'profileIcon': 1667}}, {'participantId': 2, 'player': {'platformId': 'NA', 'accountId': 98557, 'summonerName': 'MeNoHaxor', 'summonerId': 71715, 'currentPlatformId': 'NA1', 'currentAccountId': 98557, 'matchHistoryUri': '/v1/stats/player_history/NA/98557', 'profileIcon': 3205}}, {'participantId': 3, 'player': {'platformId': 'NA1', 'accountId': 238107736, 'summonerName': 'BitcoinBeatsCoin', 'summonerId': 87119170, 'currentPlatformId': 'NA1', 'currentAccountId': 238107736, 'matchHistoryUri': '/v1/stats/player_history/NA1/238107736', 'profileIcon': 18}}, {'participantId': 4, 'player': {'platformId': 'NA1', 'accountId': 44508344, 'summonerName': 'Piggy Kitten', 'summonerId': 30266347, 'currentPlatformId': 'NA1', 'currentAccountId': 44508344, 'matchHistoryUri': '/v1/stats/player_history/NA1/44508344', 'profileIcon': 3225}}, {'participantId': 5, 'player': {'platformId': 'NA', 'accountId': 32836707, 'summonerName': 'eUnited Garbage', 'summonerId': 20037104, 'currentPlatformId': 'NA1', 'currentAccountId': 32836707, 'matchHistoryUri': '/v1/stats/player_history/NA/32836707', 'profileIcon': 3266}}, {'participantId': 6, 'player': {'platformId': 'NA1', 'accountId': 50952246, 'summonerName': 'ROBERTxLEE', 'summonerId': 36488045, 'currentPlatformId': 'NA1', 'currentAccountId': 50952246, 'matchHistoryUri': '/v1/stats/player_history/NA1/50952246', 'profileIcon': 3186}}, {'participantId': 7, 'player': {'platformId': 'NA', 'accountId': 34497501, 'summonerName': 'Auberaun', 'summonerId': 21201241, 'currentPlatformId': 'NA1', 'currentAccountId': 34497501, 'matchHistoryUri': '/v1/stats/player_history/NA/34497501', 'profileIcon': 559}}, {'participantId': 8, 'player': {'platformId': 'NA1', 'accountId': 204011393, 'summonerName': 'MistyStumpey', 'summonerId': 41233933, 'currentPlatformId': 'NA1', 'currentAccountId': 204011393, 'matchHistoryUri': '/v1/stats/player_history/NA1/204011393', 'profileIcon': 3349}}, {'participantId': 9, 'player': {'platformId': 'NA1', 'accountId': 244721782, 'summonerName': '5hour energy', 'summonerId': 92319091, 'currentPlatformId': 'NA1', 'currentAccountId': 244721782, 'matchHistoryUri': '/v1/stats/player_history/NA1/244721782', 'profileIcon': 4}}, {'participantId': 10, 'player': {'platformId': 'NA', 'accountId': 36580110, 'summonerName': 'TheOddOrange', 'summonerId': 22696988, 'currentPlatformId': 'NA1', 'currentAccountId': 36580110, 'matchHistoryUri': '/v1/stats/player_history/NA/36580110', 'profileIcon': 565}}]}

# %%
info
# Out:
# {'gameCreation': 1519278966427,
#  'gameDuration': 1958,
#  'gameId': 2724594688,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '8.3.217.1022',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#    'player': {'accountId': 208040964,
#     'currentAccountId': 208040964,
#     'currentPlatformId': 'NA1',
#     'matchHistoryUri': '/v1/stats/player_history/NA1/208040964',
#     'platformId': 'NA1',
#     'profileIcon': 1667,
#     'summonerId': 45167717,
#     'summonerName': 'Bánh Bao Chiên'}},
#   {'participantId': 2,
#    'player': {'accountId': 98557,
#     'currentAccountId': 98557,
#     'currentPlatformId': 'NA1',
#     'matchHistoryUri': '/v1/stats/player_history/NA/98557',
#     'platformId': 'NA',
#     'profileIcon': 3205,
#     'summonerId': 71715,
#     'summonerName': 'MeNoHaxor'}},
#   {'participantId': 3,
#    'player': {'accountId': 238107736,
#     'currentAccountId': 238107736,
#     'currentPlatformId': 'NA1',
# ...

# %%
with open('matches.json', 'w') as file:
    json.dump(thingy, file, indent=2)

# %%
with open('matches.json', 'r') as file:
    datastore = json.load(file)

# %%
datastore
# Out:
# {'2721779898': {'lose': [{'MMR': 2137, 'championId': 98},
#    {'MMR': 1990, 'championId': 498},
#    {'MMR': 2066, 'championId': 268},
#    {'MMR': 2051, 'championId': 59},
#    {'MMR': 2338, 'championId': 16}],
#   'win': [{'MMR': 2044, 'championId': 14},
#    {'MMR': 2286, 'championId': 9},
#    {'MMR': 2035, 'championId': 67},
#    {'MMR': 1979, 'championId': 4},
#    {'MMR': 2104, 'championId': 427}]}}

# %%
thingy
# Out:
# {2721779898: {'lose': [{'MMR': 2137, 'championId': 98},
#    {'MMR': 1990, 'championId': 498},
#    {'MMR': 2066, 'championId': 268},
#    {'MMR': 2051, 'championId': 59},
#    {'MMR': 2338, 'championId': 16}],
#   'win': [{'MMR': 2044, 'championId': 14},
#    {'MMR': 2286, 'championId': 9},
#    {'MMR': 2035, 'championId': 67},
#    {'MMR': 1979, 'championId': 4},
#    {'MMR': 2104, 'championId': 427}]}}

# %%
print(participant_champs)
# Out:
# {1: 14, 2: 9, 3: 67, 4: 4, 5: 427, 6: 98, 7: 498, 8: 268, 9: 59, 10: 16}

# %%
print(champions)
# Out:
# {'Jax': 24, 'Sona': 37, 'Tristana': 18, 'Varus': 110, 'Fiora': 114, 'Singed': 27, 'TahmKench': 223, 'Leblanc': 7, 'Thresh': 412, 'Karma': 43, 'Jhin': 202, 'Rumble': 68, 'Udyr': 77, 'LeeSin': 64, 'Yorick': 83, 'Ornn': 516, 'Kayn': 141, 'Kassadin': 38, 'Sivir': 15, 'MissFortune': 21, 'Draven': 119, 'Yasuo': 157, 'Kayle': 10, 'Shaco': 35, 'Renekton': 58, 'Hecarim': 120, 'Fizz': 105, 'KogMaw': 96, 'Maokai': 57, 'Lissandra': 127, 'Jinx': 222, 'Urgot': 6, 'Fiddlesticks': 9, 'Galio': 3, 'Pantheon': 80, 'Talon': 91, 'Gangplank': 41, 'Ezreal': 81, 'Gnar': 150, 'Teemo': 17, 'Annie': 1, 'Mordekaiser': 82, 'Azir': 268, 'Kennen': 85, 'Riven': 92, 'Chogath': 31, 'Aatrox': 266, 'Poppy': 78, 'Taliyah': 163, 'Illaoi': 420, 'Heimerdinger': 74, 'Alistar': 12, 'XinZhao': 5, 'Lucian': 236, 'Volibear': 106, 'Sejuani': 113, 'Nidalee': 76, 'Garen': 86, 'Leona': 89, 'Zed': 238, 'Blitzcrank': 53, 'Rammus': 33, 'Velkoz': 161, 'Caitlyn': 51, 'Trundle': 48, 'Kindred': 203, 'Quinn': 133, 'Ekko': 245, 'Nami': 267,
# ...

# %%
# Set up network function
def model_fn(features, labels, mode):
    if mode == tf.estimator.

# %%
# train network
classifier = tf.estimator.Estimator(model_fn=model_fn, model_dir="/tmp/league_win_model")
